# %%
# !pip install xlrd
# !pip install tables
from global_setting import NEWS_PATH_LIST
from main import run_data_processing
from multiprocessing import Pool
news_path_list = [path for path in NEWS_PATH_LIST if 
                  int(path.split('/')[-1].split('-')[0])  in [2005, 2006, 2007]]
# Out:
# ...
# scikit-umfpack 0.3.2 has requirement numpy>=1.15.3, but you'll have numpy 1.15.1 which is incompatible.
# menpo 0.8.1 has requirement matplotlib<2.0,>=1.4, but you'll have matplotlib 2.2.3 which is incompatible.
# menpo 0.8.1 has requirement pillow<5.0,>=3.0, but you'll have pillow 5.2.0 which is incompatible.
# menpo 0.8.1 has requirement scipy<1.0,>=0.16, but you'll have scipy 1.1.0 which is incompatible.
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# scikit-umfpack 0.3.2 has requirement numpy>=1.15.3, but you'll have numpy 1.15.1 which is incompatible.
# menpo 0.8.1 has requirement matplotlib<2.0,>=1.4, but you'll have matplotlib 2.2.3 which is incompatible.
# menpo 0.8.1 has requirement pillow<5.0,>=3.0, but you'll have pillow 5.2.0 which is incompatible.
# menpo 0.8.1 has requirement scipy<1.0,>=0.16, but you'll have scipy 1.1.0 which is incompatible.
# ...

# %%
pool = Pool(8)
pool.map(run_data_processing, news_path_list)
# Out:
# 2020-01-01 21:08:07.799460 dsf_2006_df is loaded!
# 2020-01-01 21:08:07.826116 dsf_2006_df is loaded!
# 2020-01-01 21:08:07.824027 Working on /floyd/input/news/2006-02_cleaned.pkl
# 2020-01-01 21:08:07.829473 Working on /floyd/input/news/2006-06_cleaned.pkl
# 2020-01-01 21:08:07.834006 dsf_2005_df is loaded!
# 2020-01-01 21:08:07.838489 Working on /floyd/input/news/2005-01_cleaned.pkl
# 2020-01-01 21:08:07.866124 dsf_2006_df is loaded!
# 2020-01-01 21:08:07.869039 Working on /floyd/input/news/2006-08_cleaned.pkl
# 2020-01-01 21:08:07.872777 dsf_2005_df is loaded!
# 2020-01-01 21:08:07.878950 Working on /floyd/input/news/2005-05_cleaned.pkl
# 2020-01-01 21:08:07.891908 dsf_2005_df is loaded!
# 2020-01-01 21:08:07.892214 dsf_2007_df is loaded!
# 2020-01-01 21:08:07.897103 Working on /floyd/input/news/2005-07_cleaned.pkl
# 2020-01-01 21:08:07.897601 Working on /floyd/input/news/2007-02_cleaned.pkl
# 2020-01-01 21:08:07.910617 dsf_2007_df is loaded!
# ...
